# %% [markdown]
# <a href="https://colab.research.google.com/github/theakash07/100_Days_Machine_Learning/blob/main/Day_15_Working_with_CSV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/placement.csv')

# %%
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %% [markdown]
# **Opening a Csv file with URL**

# %%
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/laxmimerit/All-CSV-ML-Data-Files-Download/master/worldstats.csv"
headers = {"User-Agent":"Mozilla/5.0 (Machintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url, headers = headers)
data = StringIO(req.text)
data2 = pd.read_csv(data)

# %%
data2.head(5)
# Out:
#       country  year   Population           GDP
# 0  Arab World  2015  392022276.0  2.530102e+12
# 1  Arab World  2014  384222592.0  2.873600e+12
# 2  Arab World  2013  376504253.0  2.846994e+12
# 3  Arab World  2012  368802611.0  2.773270e+12
# 4  Arab World  2011  361031820.0  2.497945e+12

# %%
pd.read_csv('/content/sample-3.tsv',sep="\t",names=['Class','rating','Status'])
# Out:
#       Class rating                                             Status
# 0     To Do    NaN                                    1/3 completed
# 1       NaN    NaN                                                NaN
# 2         ✓   Date                                               Task
# 3      TRUE    7/9    Type anything into column A to complete an item
# 4     FALSE    8/9  Change the styling of completed items under 'F...
# 5     FALSE    9/9  Sort items using the drop-down arrows next to ...
# 6     FALSE    NaN                                                NaN
# 7     FALSE    NaN                                                NaN
# 8     FALSE    NaN                                                NaN
# 9     FALSE    NaN                                                NaN
# 10    FALSE    NaN                                                NaN
# 11    FALSE    NaN                                                NaN
# ...

# %% [markdown]
# **INdex_col Parameter**

# %%
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
pd.read_csv('/content/placement.csv',index_col='Unnamed: 0') #if you want to start your index column from there..
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %% [markdown]
# **Header parameter**

# %%
pd.read_csv('/content/placement.csv',header = 1) #if you want to start the header from specific location you co perform this way
# Out:
#      0  6.8  123.0  1
# 0    1  5.9  106.0  0
# 1    2  5.3  121.0  0
# 2    3  7.4  132.0  1
# 3    4  5.8  142.0  0
# 4    5  7.1   48.0  1
# ..  ..  ...    ... ..
# 94  95  4.3  200.0  0
# 95  96  4.4   42.0  0
# 96  97  6.7  182.0  1
# 97  98  6.3  103.0  1
# 98  99  6.2  113.0  1
#
# [99 rows x 4 columns]

# %% [markdown]
# if you want only specific column from the dataset you can use this code.
# **usecols**

# %%
pd.read_csv('/content/placement.csv',usecols=['cgpa','iq'])
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %% [markdown]
# If you want to skiprows in dataset you can use
# this command ***SKiprows***

# %%
pd.read_csv('/content/placement.csv',skiprows=[0,1])
# Out:
#      1  5.9  106.0  0
# 0    2  5.3  121.0  0
# 1    3  7.4  132.0  1
# 2    4  5.8  142.0  0
# 3    5  7.1   48.0  1
# 4    6  5.7  143.0  0
# ..  ..  ...    ... ..
# 93  95  4.3  200.0  0
# 94  96  4.4   42.0  0
# 95  97  6.7  182.0  1
# 96  98  6.3  103.0  1
# 97  99  6.2  113.0  1
#
# [98 rows x 4 columns]

# %% [markdown]
# If you want to import only nrows in dataset you can use
# this command ***nrows**

# %%
pd.read_csv('/content/placement.csv',nrows=50)
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# 5            5   7.1   48.0          1
# 6            6   5.7  143.0          0
# 7            7   5.0   63.0          0
# 8            8   6.1  156.0          0
# 9            9   5.1   66.0          0
# 10          10   6.0   45.0          1
# 11          11   6.9  138.0          1
# 12          12   5.4  139.0          0
# 13          13   6.4  116.0          1
# 14          14   6.1  103.0          0
# 15          15   5.1  176.0          0
# 16          16   5.2  224.0          0
# 17          17   3.3  183.0          0
# 18          18   4.0  100.0          0
# 19          19   5.2  132.0          0
# 20          20   6.6  120.0          1
# 21          21   7.1  151.0          1
# 22          22   4.9  120.0          0
# ...

# %%
df1=pd.read_csv('/content/placement.csv',nrows=50)

# %%
df1.iloc[:,1:] #this iloc command is use to remove the columns
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# 5    7.1   48.0          1
# 6    5.7  143.0          0
# 7    5.0   63.0          0
# 8    6.1  156.0          0
# 9    5.1   66.0          0
# 10   6.0   45.0          1
# 11   6.9  138.0          1
# 12   5.4  139.0          0
# 13   6.4  116.0          1
# 14   6.1  103.0          0
# 15   5.1  176.0          0
# 16   5.2  224.0          0
# 17   3.3  183.0          0
# 18   4.0  100.0          0
# 19   5.2  132.0          0
# 20   6.6  120.0          1
# 21   7.1  151.0          1
# 22   4.9  120.0          0
# 23   4.7   87.0          0
# 24   4.7  121.0          0
# 25   5.0   91.0          0
# 26   7.0  199.0          1
# 27   6.0  124.0          1
# 28   5.2   90.0          0
# 29   7.0  112.0          1
# 30   7.6  128.0          1
# 31   3.9  109.0          0
# 32   7.0  139.0          1
# ...

# %%
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/prm2711/python-recommender/master/zomato.csv"
headers = {"User-Agent":"Mozilla/5.0 (Machintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
request = requests.get(url, headers = headers)
data = StringIO(request.text)
data3 = pd.read_csv(data,encoding='latin-1')

# %%
data3.head(5)
# Out:
#    Restaurant ID         Restaurant Name                          Cuisines  \
# 0        6317637        Le Petit Souffle        French, Japanese, Desserts
# 1        6304287        Izakaya Kikufuji                          Japanese
# 2        6300002  Heat - Edsa Shangri-La  Seafood, Asian, Filipino, Indian
# 3        6318506                    Ooma                   Japanese, Sushi
# 4        6314302             Sambo Kojin                  Japanese, Korean
#
#    Average Cost for two          Currency Has Table booking  \
# 0                  1100  Botswana Pula(P)               Yes
# 1                  1200  Botswana Pula(P)               Yes
# 2                  4000  Botswana Pula(P)               Yes
# 3                  1500  Botswana Pula(P)                No
# 4                  1500  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu  Price range  \
# 0                  No                No                   No            3
# ...

# %% [markdown]
# *Skipping Bad Lines*

# %%
pd.read_csv('/content/placement.csv',error_bad_lines=False)

# %% [markdown]
# Convert datatypes into specific datatypes using *dtype* function

# %%
pd.read_csv('/content/placement.csv',dtype={'placement':float})
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0        1.0
# 1            1   5.9  106.0        0.0
# 2            2   5.3  121.0        0.0
# 3            3   7.4  132.0        1.0
# 4            4   5.8  142.0        0.0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0        0.0
# 96          96   4.4   42.0        0.0
# 97          97   6.7  182.0        1.0
# 98          98   6.3  103.0        1.0
# 99          99   6.2  113.0        1.0
#
# [100 rows x 4 columns]

# %% [markdown]
# Converter techniques

# %%
def rename(name):
  if name == "Dark Green":
    return "DG"
  else:
    return name

# %%
rename("Dark Green")
# Out:
# 'DG'

# %%
pd.read_csv(data3,converters={'Rating color':rename})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-7f494e3badb7> in <cell line: 1>()
# ----> 1 pd.read_csv(data3,converters={'Rating color':rename})
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
data3.head(5)
# Out:
#    Restaurant ID         Restaurant Name                          Cuisines  \
# 0        6317637        Le Petit Souffle        French, Japanese, Desserts
# 1        6304287        Izakaya Kikufuji                          Japanese
# 2        6300002  Heat - Edsa Shangri-La  Seafood, Asian, Filipino, Indian
# 3        6318506                    Ooma                   Japanese, Sushi
# 4        6314302             Sambo Kojin                  Japanese, Korean
#
#    Average Cost for two          Currency Has Table booking  \
# 0                  1100  Botswana Pula(P)               Yes
# 1                  1200  Botswana Pula(P)               Yes
# 2                  4000  Botswana Pula(P)               Yes
# 3                  1500  Botswana Pula(P)                No
# 4                  1500  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu  Price range  \
# 0                  No                No                   No            3
# ...

# %% [markdown]
# na_values : case

# %%
pd.read_csv(data3,na_values=['Yes'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-e1b1ae594b16> in <cell line: 1>()
# ----> 1 pd.read_csv(data3,na_values=['Yes'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     910     kwds.update(kwds_defaults)
#     911
# ...

# %% [markdown]
# ****
